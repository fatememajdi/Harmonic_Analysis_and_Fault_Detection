# %%
import sys

# %%
# Add project root to path
sys.path.append('../src')
from evaluate import batch_analyze_folder
fault_freqs = {
    "FTF": {"freq": 12.3, "threshold_ratio": 2},
    # "BPFO": {"freq": 45.1, "threshold_ratio": 0.2},
    "Electrical": {"freq": 100.0, "threshold_ratio": 1.5}
}
batch_analyze_folder('../data/raw','../data/peocessed', fault_freqs)
# Out:
# Processing file: 2511RM1-02V  M-2V_ Vel (4_30_2025 08_51_37) - Time Signal.txt
#         Fault         Match_Type  Harmonic  Peak_Freq  Amplitude  Delta_amp
# 0  Electrical  Exact_On_Harmonic      49.5     49.500   0.122893   0.061447
# 1         FTF      Near_Harmonic      99.0     98.375   0.303057   0.199153
# 2  Electrical  Exact_On_Harmonic     165.0    165.000   0.021908   0.010954
# Processing file: 2511RM1-02V  M-2V_ Vel (4_5_2025 07_52_44) - Time Signal.txt
#         Fault         Match_Type  Harmonic  Peak_Freq  Amplitude  Delta_amp
# 0  Electrical  Exact_On_Harmonic      49.5     49.500   0.108449   0.054224
# 1         FTF  Exact_On_Harmonic      82.5     82.625   0.017740   0.001114
# 2         FTF      Near_Harmonic      99.0     98.500   0.207731   0.180997
# 3         FTF  Exact_On_Harmonic     115.5    115.625   0.015443   0.010917
# 4         FTF  Exact_On_Harmonic     132.0    132.125   0.010249   0.008543
# ...
