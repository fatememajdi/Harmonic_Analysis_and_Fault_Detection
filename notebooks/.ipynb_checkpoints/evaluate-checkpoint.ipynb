# %%
import sys

# %%
sys.path.append('../src')
from evaluate import batch_analyze_folder

faults = [("BPFO", 49.5), ("BPFI", 33)]

batch_analyze_folder('../data/raw','../data/peocessed', faults)
# Out:
# Processing file: 2511RM1-02V  M-2V_ Vel (4_30_2025 08_51_37) - Time Signal.txt
#    Type   Freq    Amp
# 0  BPFI  32.25  0.161
# 1  BPFO  49.50  0.152
# 2   Elc  98.38  0.375
# Processing file: 2511RM1-02V  M-2V_ Vel (4_5_2025 07_52_44) - Time Signal.txt
#    Type  Freq    Amp
# 0  BPFI  33.0  0.032
# 1  BPFO  49.5  0.136
# 2   Elc  98.5  0.260
# Processing file: 2511RM1-01H  M-1H_ Vel (4_5_2025 07_46_52) - Time Signal.txt
#    Type   Freq    Amp
# 0  BPFI  32.25  0.734
# 1  BPFO  49.50  1.000
# 2   Elc  98.38  0.549
# Processing file: 2511RM1-02H  M-2H_ Vel (4_30_2025 08_50_14) - Time Signal.txt
#    Type   Freq    Amp
# 0  BPFI  32.25  0.087
# 1  BPFO  49.50  0.118
# 2   Elc  98.50  0.150
# Processing file: 2511RM1-02A  M-2A_ Vel (4_30_2025 08_47_32) - Time Signal.txt
#    Type   Freq    Amp
# 0  BPFI  32.25  0.232
# 1  BPFO  49.50  0.232
# 2   Elc  98.50  1.000
# Processing file: 2511RM1-01V  M-1V_ Vel (4_30_2025 08_49_32) - Time Signal.txt
#    Type   Freq    Amp
# ...
